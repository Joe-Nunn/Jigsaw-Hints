# %%
import matplotlib.pyplot as plt
import numpy
import os
from trainer import Trainer

cwd = os.getcwd()
jigsaw_trainer = Trainer(os.path.join(cwd, "JigsawDataset"), "data.csv")
losses, test_set_accuracy, train_set_accuracy = jigsaw_trainer.train()

plt.plot(test_set_accuracy, label="Test set accuracy")
plt.plot(train_set_accuracy, label="Train set accuracy")
plt.plot(losses, label="Loss")
plt.xlabel("Iterations")
plt.legend()
plt.title("Training results")
plt.show()
# Out:
# Starting training on cuda
# Run 1:
# 	 Loss: 0.6931847184896469
# 	 Test set accuracy: 0.48360655737704916
# 	 Train set accuracy: 0.5040983606557377
# Run 2:
# 	 Loss: 0.6929121017456055
# 	 Test set accuracy: 0.48360655737704916
# 	 Train set accuracy: 0.5040983606557377
# Run 3:
# 	 Loss: 0.6924086697399616
# 	 Test set accuracy: 0.6188524590163934
# 	 Train set accuracy: 0.6465163934426229
# Run 4:
# 	 Loss: 0.6868928223848343
# 	 Test set accuracy: 0.6967213114754098
# 	 Train set accuracy: 0.6639344262295082
# Run 5:
# 	 Loss: 0.6313121505081654
# 	 Test set accuracy: 0.7459016393442623
# 	 Train set accuracy: 0.6844262295081968
# Run 6:
# 	 Loss: 0.5904804579913616
# 	 Test set accuracy: 0.6967213114754098
# 	 Train set accuracy: 0.673155737704918
# Run 7:
# 	 Loss: 0.5839562825858593
# 	 Test set accuracy: 0.7131147540983607
# 	 Train set accuracy: 0.694672131147541
# Run 8:
# 	 Loss: 0.5682254880666733
# 	 Test set accuracy: 0.7581967213114754
# ...
