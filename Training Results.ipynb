# %%
import matplotlib.pyplot as plt
import numpy
import os
from trainer import Trainer

cwd = os.getcwd()
jigsaw_trainer = Trainer(os.path.join(cwd, "JigsawDataset"), "data.csv")
losses, test_set_accuracy, train_set_accuracy = jigsaw_trainer.train()

plt.plot(test_set_accuracy, label="Test set accuracy")
plt.plot(train_set_accuracy, label="Train set accuracy")
plt.plot(losses, label="Loss")
plt.xlabel("Iterations")
plt.legend()
plt.title("Training results")
plt.show()
# Out:
# Starting training on cuda
# Run 1:
# 	 Loss: 0.6960019373124645
# 	 Test set accuracy: 0.5081967213114754
# 	 Train set accuracy: 0.4979508196721312
# Run 2:
# 	 Loss: 0.6937348092755964
# 	 Test set accuracy: 0.4918032786885246
# 	 Train set accuracy: 0.5020491803278688
# Run 3:
# 	 Loss: 0.6940210999981049
# 	 Test set accuracy: 0.4918032786885246
# 	 Train set accuracy: 0.5020491803278688
# Run 4:
# 	 Loss: 0.6938372792736176
# 	 Test set accuracy: 0.48770491803278687
# 	 Train set accuracy: 0.5184426229508197
# Run 5:
# 	 Loss: 0.6933791810466398
# 	 Test set accuracy: 0.5081967213114754
# 	 Train set accuracy: 0.4979508196721312
# Run 6:
# 	 Loss: 0.6931931934049053
# 	 Test set accuracy: 0.5286885245901639
# 	 Train set accuracy: 0.5389344262295082
# Run 7:
# 	 Loss: 0.6924206037675181
# 	 Test set accuracy: 0.4918032786885246
# 	 Train set accuracy: 0.5020491803278688
# Run 8:
# 	 Loss: 0.6930087151065949
# 	 Test set accuracy: 0.4713114754098361
# 	 Train set accuracy: 0.5266393442622951
# Run 9:
# 	 Loss: 0.692211764474069
# 	 Test set accuracy: 0.4959016393442623
# 	 Train set accuracy: 0.5450819672131147
# Run 10:
# 	 Loss: 0.692348841697939
# 	 Test set accuracy: 0.5163934426229508
# 	 Train set accuracy: 0.5430327868852459
# Run 11:
# 	 Loss: 0.6914607747908561
# 	 Test set accuracy: 0.4918032786885246
# 	 Train set accuracy: 0.5092213114754098
# Run 12:
# 	 Loss: 0.6910503756615424
# 	 Test set accuracy: 0.48770491803278687
# 	 Train set accuracy: 0.507172131147541
